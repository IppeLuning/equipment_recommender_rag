# %% [markdown]
# # Hyperparameter tuning
#
# This model takes a lot of time to run. Therefore, we are unable to performs techniques such as parameter tuning. Therefore, we do check the difference between the main decisions for this specific model. But we d
